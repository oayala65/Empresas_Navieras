# %%
import pandas as pd

# Cargar el archivo Excel
file_path = "TAGUATO_19_03_2025-13_07_18_completo.xlsx"  # Reemplaza con la ubicación de tu archivo
df = pd.read_excel(file_path)

# Ver las primeras filas
df.head()
# Out:
#   DATE/TIME(America/Asuncion)  Carga Diario  Caudalímetros Total  Ecosonda  \
# 0         01-03-2025 14:05:02       40130.0                  NaN       NaN
# 1         01-03-2025 14:15:12       40130.0                  NaN       NaN
# 2         01-03-2025 14:25:30       40130.0                  NaN       NaN
# 3         01-03-2025 14:35:42       40130.0                  NaN       NaN
# 4         01-03-2025 14:45:52       40130.0                  NaN       NaN
#
#    Flow Rate Diario  Flow Rate Gen. BR  Flow Rate Gen. STB  \
# 0               0.0               11.9                 0.0
# 1               0.0               11.5                 0.0
# 2               0.0               11.6                 0.0
# 3               0.0               14.3                 0.0
# 4               0.0               12.7                 0.0
#
#    Flow Rate Prop. BR  Flow Rate Prop. STB    Latitud  ...   TK 4 STB  \
# 0                 0.0                  0.0 -25.568506  ...  2906.7606
# 1                 0.0                  0.0 -25.568506  ...  2906.7606
# 2                 0.0                  0.0 -25.568506  ...  2906.7606
# 3                 0.0                  0.0 -25.568506  ...  2906.7606
# 4                 0.0                  0.0 -25.568506  ...  2931.0147
#
#    TK 5 BR  TK 5 STB  TK DIARIO  Trip Volume Gen. BR  Trip Volume Gen. STB  \
# 0      0.0   52.6108     1102.8                223.0                   3.0
# 1      0.0   50.2194     1102.8                225.0                   3.0
# 2      0.0   50.2194     1093.8                227.0                   3.0
# 3      0.0   50.2194     1093.8                229.0                   3.0
# 4      0.0   52.6108     1093.8                231.0                   3.0
#
#    Trip Volume Prop. BR  Trip Volume Prop. STB  Velocidad  \
# 0               62849.0                70986.0        0.0
# 1               62849.0                70986.0        0.0
# 2               62849.0                70986.0        0.0
# 3               62849.0                70986.0        0.0
# 4               62849.0                70986.0        0.0
#
#    Velocidad del Viento
# 0                  5.50
# 1                  4.06
# 2                  5.40
# 3                  4.68
# 4                  4.62
#
# [5 rows x 65 columns]

# %%
df.to_csv('taguato_completo.csv', index=False)

# %%
df=df.drop('DATE/TIME(America/Asuncion)',axis=1)

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Calcular la matriz de correlación
# corr_matrix = df.corr()

# # Graficar la matriz de correlación con un mapa de calor
# plt.figure(figsize=(12, 8))
# sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
# plt.title("Matriz de Correlación - Todos contra Todos")
# plt.show()

# %%
# sns.pairplot(df, diag_kind="kde", plot_kws={"alpha": 0.5})
# plt.show()

# %%
# print(df.corr()["Flow Rate Prop. BR"].sort_values(ascending=False))

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer

# # Eliminar filas donde las variables objetivo sean NaN
df_clean = df.dropna(subset=["Flow Rate Prop. BR", "Flow Rate Prop. STB"])

# Definir variables de entrada y salida
X = df_clean.drop(columns=["Flow Rate Prop. BR", "Flow Rate Prop. STB"])
y_BR = df_clean["Flow Rate Prop. BR"]
y_STB = df_clean["Flow Rate Prop. STB"]

# Sin Perder Datos
# Rellenar valores NaN con la mediana de cada variable objetivo
# Rellenar NaN en y_BR e y_STB con la mediana
# df["Flow Rate Prop. BR"] = df["Flow Rate Prop. BR"].fillna(df["Flow Rate Prop. BR"].median())
# df["Flow Rate Prop. STB"] = df["Flow Rate Prop. STB"].fillna(df["Flow Rate Prop. STB"].median())

# # Definir X e y
# X = df.drop(columns=["Flow Rate Prop. BR", "Flow Rate Prop. STB"])
# y_BR = df["Flow Rate Prop. BR"]
# y_STB = df["Flow Rate Prop. STB"]


# Manejar valores nulos con la mediana
imputer = SimpleImputer(strategy="median")
X_imputed = imputer.fit_transform(X)

# Dividir los datos en entrenamiento y prueba
X_train, X_test, y_train_BR, y_test_BR = train_test_split(X_imputed, y_BR, test_size=0.4, random_state=42)
X_train, X_test, y_train_STB, y_test_STB = train_test_split(X_imputed, y_STB, test_size=0.4, random_state=42)

# Eliminar filas donde las variables objetivo sean NaN
df_clean = df.dropna(subset=["Flow Rate Prop. BR", "Flow Rate Prop. STB"])


# # Entrenar modelos de regresión lineal
# model_BR = LinearRegression()
# model_BR.fit(X_train, y_train_BR)

# model_STB = LinearRegression()
# model_STB.fit(X_train, y_train_STB)


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gplearn.genetic import SymbolicRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Definir las variables de entrada y salida
X = df.drop(columns=["Flow Rate Prop. BR", "Flow Rate Prop. STB"])  # Usamos todas las variables excepto la salida
y_BR = df["Flow Rate Prop. BR"]
y_STB = df["Flow Rate Prop. STB"]

# Eliminar NaN para evitar errores
df_clean = df.dropna(subset=["Flow Rate Prop. BR", "Flow Rate Prop. STB"])
X = df_clean.drop(columns=["Flow Rate Prop. BR", "Flow Rate Prop. STB"])
y_BR = df_clean["Flow Rate Prop. BR"]
y_STB = df_clean["Flow Rate Prop. STB"]

# Dividir en entrenamiento y prueba
X_train, X_test, y_train_BR, y_test_BR = train_test_split(X, y_BR, test_size=0.2, random_state=42)


# Crear el modelo de regresión simbólica
model_BR = SymbolicRegressor(
    population_size=500,   # Tamaño de la población en cada generación
    generations=50,        # Número de generaciones
    function_set=('add', 'sub', 'mul', 'div', 'sin', 'cos', 'sqrt', 'log'),  # Operaciones permitidas
    metric='mse',          # Minimizar el error cuadrático medio
    verbose=1,             # Mostrar progreso
    random_state=42
)

# Entrenar el modelo
model_BR.fit(X_train, y_train_BR)

# Hacer predicciones
y_pred_BR = model_BR.predict(X_test)

# Evaluar el modelo
mse_BR = mean_squared_error(y_test_BR, y_pred_BR)
r2_BR = r2_score(y_test_BR, y_pred_BR)

print(f"Error Cuadrático Medio (MSE): {mse_BR:.4f}")
print(f"Coeficiente de Determinación (R²): {r2_BR:.4f}")

# Mostrar la ecuación encontrada
print("Ecuación simbólica encontrada:")
print(model_BR._program)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Predicciones en el conjunto de prueba
y_pred_BR_test = model_BR.predict(X_test)
y_pred_STB_test = model_STB.predict(X_test)

# Cálculo de métricas para Flow Rate Prop. BR
mae_BR = mean_absolute_error(y_test_BR, y_pred_BR_test)
mse_BR = mean_squared_error(y_test_BR, y_pred_BR_test)
rmse_BR = np.sqrt(mse_BR)
r2_BR = r2_score(y_test_BR, y_pred_BR_test)

# Cálculo de métricas para Flow Rate Prop. STB
mae_STB = mean_absolute_error(y_test_STB, y_pred_STB_test)
mse_STB = mean_squared_error(y_test_STB, y_pred_STB_test)
rmse_STB = np.sqrt(mse_STB)
r2_STB = r2_score(y_test_STB, y_pred_STB_test)

# Mostrar resultados
print("**Errores para Flow Rate Prop. BR:**")
print(f"MAE: {mae_BR:.2f}")
print(f"MSE: {mse_BR:.2f}")
print(f"RMSE: {rmse_BR:.2f}")
print(f"R²: {r2_BR:.4f}\n")

print("**Errores para Flow Rate Prop. STB:**")
print(f"MAE: {mae_STB:.2f}")
print(f"MSE: {mse_STB:.2f}")
print(f"RMSE: {rmse_STB:.2f}")
print(f"R²: {r2_STB:.4f}")
# Out:
# **Errores para Flow Rate Prop. BR:**
# MAE: 34.60
# MSE: 6158.00
# RMSE: 78.47
# R²: 0.4275
#
# **Errores para Flow Rate Prop. STB:**
# MAE: 10.30
# MSE: 1181.62
# RMSE: 34.37
# R²: 0.7866

# %%
# Eliminando los NaN

#**Errores para Flow Rate Prop. BR:**
# MAE: 35.62
# MSE: 5202.04
# RMSE: 72.13
# R²: 0.5607

# **Errores para Flow Rate Prop. STB:**
# MAE: 10.40
# MSE: 1189.18
# RMSE: 34.48
# R²: 0.7679

# %%
# Rellenando con la mediana

#**Errores para Flow Rate Prop. BR:**
#MAE: 34.23
#MSE: 3594.64
#RMSE: 59.96
#R²: 0.6516

#**Errores para Flow Rate Prop. STB:**
#MAE: 8.53
#MSE: 272.98
#RMSE: 16.52
#R²: 0.9389

# %% [markdown]
# <!-- **Errores para Flow Rate Prop. BR:**
# MAE: 34.23
# MSE: 3594.64
# RMSE: 59.96
# R²: 0.6516
#
# **Errores para Flow Rate Prop. STB:**
# MAE: 8.53
# MSE: 272.98
# RMSE: 16.52
# R²: 0.9389 -->

# %%
# Generar datos de entrada para la gráfica
X_median = np.median(X_train, axis=0)  # Valores fijos en la mediana
X_fixed_BR = np.tile(X_median, (100, 1))
X_fixed_STB = np.tile(X_median, (100, 1))

# Modificar las columnas correspondientes
rack_br_idx = list(df.columns).index("Rack Prop. BR") - 1
rack_stb_idx = list(df.columns).index("Rack Prop. STB") - 1

x_range_BR = np.linspace(df["Rack Prop. BR"].min(), df["Rack Prop. BR"].max(), 100)
X_fixed_BR[:, rack_br_idx] = x_range_BR
y_pred_BR = model_BR.predict(X_fixed_BR)

x_range_STB = np.linspace(df["Rack Prop. STB"].min(), df["Rack Prop. STB"].max(), 100)
X_fixed_STB[:, rack_stb_idx] = x_range_STB
y_pred_STB = model_STB.predict(X_fixed_STB)

# Crear gráficos
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Gráfico para la hélice de babor (BR)
sns.scatterplot(x=df["Rack Prop. BR"], y=df["Flow Rate Prop. BR"], ax=axes[0], color="blue", alpha=0.5)
axes[0].plot(x_range_BR, y_pred_BR, color="black", linewidth=2)
axes[0].set_title("Regresión Lineal: Rack Prop. BR vs Flow Rate Prop. BR")
axes[0].set_xlabel("Rack Prop. BR (Ángulo)")
axes[0].set_ylabel("Flow Rate Prop. BR (Caudal)")

# Gráfico para la hélice de estribor (STB)
sns.scatterplot(x=df["Rack Prop. STB"], y=df["Flow Rate Prop. STB"], ax=axes[1], color="red", alpha=0.5)
axes[1].plot(x_range_STB, y_pred_STB, color="black", linewidth=2)
axes[1].set_title("Regresión Lineal: Rack Prop. STB vs Flow Rate Prop. STB")
axes[1].set_xlabel("Rack Prop. STB (Ángulo)")
axes[1].set_ylabel("Flow Rate Prop. STB (Caudal)")

plt.tight_layout()
plt.show()

# %%
import shap

# Crear el objeto SHAP explainer
explainer = shap.Explainer(model_BR, X)

# Calcular los valores SHAP
shap_values = explainer(X)

# Resumen gráfico de SHAP
shap.summary_plot(shap_values, X)

# %%
import shap

# Crear el objeto SHAP explainer
explainer = shap.Explainer(model_STB, X)

# Calcular los valores SHAP
shap_values = explainer(X)

# Resumen gráfico de SHAP
shap.summary_plot(shap_values, X)

# %%
df.isna().sum()
# Out:
# Carga Diario                2
# Caudalímetros Total      2318
# Ecosonda                 1846
# Flow Rate Diario            2
# Flow Rate Gen. BR           2
#                          ...
# Trip Volume Gen. STB        2
# Trip Volume Prop. BR        2
# Trip Volume Prop. STB       2
# Velocidad                   4
# Velocidad del Viento        2
# Length: 64, dtype: int64

# %%
len(df)
# Out:
# 2532

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gplearn.genetic import SymbolicRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Definir las variables de entrada y salida
X = df.drop(columns=["Flow Rate Prop. BR", "Flow Rate Prop. STB"])  # Usamos todas las variables excepto la salida
y_BR = df["Flow Rate Prop. BR"]
y_STB = df["Flow Rate Prop. STB"]

# Eliminar NaN para evitar errores
df_clean = df.dropna(subset=["Flow Rate Prop. BR", "Flow Rate Prop. STB"])
X = df_clean.drop(columns=["Flow Rate Prop. BR", "Flow Rate Prop. STB"])
y_BR = df_clean["Flow Rate Prop. BR"]
y_STB = df_clean["Flow Rate Prop. STB"]

# Dividir en entrenamiento y prueba
X_train, X_test, y_train_BR, y_test_BR = train_test_split(X, y_BR, test_size=0.2, random_state=42)

# Crear el modelo de regresión simbólica
model_BR = SymbolicRegressor(
    population_size=500,   # Tamaño de la población en cada generación
    generations=50,        # Número de generaciones
    function_set=('add', 'sub', 'mul', 'div', 'sin', 'cos', 'sqrt', 'log'),  # Operaciones permitidas
    metric='mse',          # Minimizar el error cuadrático medio
    verbose=1,             # Mostrar progreso
    random_state=42
)

# Entrenar el modelo
model_BR.fit(X_train, y_train_BR)

# Hacer predicciones
y_pred_BR = model_BR.predict(X_test)

# Evaluar el modelo
mse_BR = mean_squared_error(y_test_BR, y_pred_BR)
r2_BR = r2_score(y_test_BR, y_pred_BR)

print(f"Error Cuadrático Medio (MSE): {mse_BR:.4f}")
print(f"Coeficiente de Determinación (R²): {r2_BR:.4f}")

# Mostrar la ecuación encontrada
print("Ecuación simbólica encontrada:")
print(model_BR._program)
# Out:
# /home/oayala65/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 33
#      23 model_BR = SymbolicRegressor(
#      24     population_size=500,   # Tamaño de la población en cada generación
#      25     generations=50,        # Número de generaciones
#    (...)
#      29     random_state=42
#      30 )
#      32 # Entrenar el modelo
# ---> 33 model_BR.fit(X_train, y_train_BR)
#      35 # Hacer predicciones
#      36 y_pred_BR = model_BR.predict(X_test)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/gplearn/genetic.py:312, in BaseSymbolic.fit(self, X, y, sample_weight)
#     309     self.n_classes_ = len(self.classes_)
#     311 else:
# --> 312     X, y = self._validate_data(X, y, y_numeric=True)
#     314 hall_of_fame = self.hall_of_fame
#     315 if hall_of_fame is None:
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/base.py:480, in BaseEstimator._validate_data(self, *args, **kwargs)
#     473 def _validate_data(self, *args, **kwargs):
#     474     warnings.warn(
#     475         "`BaseEstimator._validate_data` is deprecated in 1.6 and will be removed "
#     476         "in 1.7. Use `sklearn.utils.validation.validate_data` instead. This "
#     477         "function becomes public and is part of the scikit-learn developer API.",
#     478         FutureWarning,
#     479     )
# --> 480     return validate_data(self, *args, **kwargs)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/utils/validation.py:2961, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2959         y = check_array(y, input_name="y", **check_y_params)
#    2960     else:
# -> 2961         X, y = check_X_y(X, y, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/utils/validation.py:1370, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1364     raise ValueError(
#    1365         f"{estimator_name} requires y to be passed, but the target y is None"
#    1366     )
#    1368 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1370 X = check_array(
#    1371     X,
#    1372     accept_sparse=accept_sparse,
#    1373     accept_large_sparse=accept_large_sparse,
#    1374     dtype=dtype,
#    1375     order=order,
#    1376     copy=copy,
#    1377     force_writeable=force_writeable,
#    1378     ensure_all_finite=ensure_all_finite,
#    1379     ensure_2d=ensure_2d,
#    1380     allow_nd=allow_nd,
#    1381     ensure_min_samples=ensure_min_samples,
#    1382     ensure_min_features=ensure_min_features,
#    1383     estimator=estimator,
#    1384     input_name="X",
#    1385 )
#    1387 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1389 check_consistent_length(X, y)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/utils/validation.py:1107, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1101     raise ValueError(
#    1102         "Found array with dim %d. %s expected <= 2."
#    1103         % (array.ndim, estimator_name)
#    1104     )
#    1106 if ensure_all_finite:
# -> 1107     _assert_all_finite(
#    1108         array,
#    1109         input_name=input_name,
#    1110         estimator_name=estimator_name,
#    1111         allow_nan=ensure_all_finite == "allow-nan",
#    1112     )
#    1114 if copy:
#    1115     if _is_numpy_namespace(xp):
#    1116         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/utils/validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/utils/validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# SymbolicRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
