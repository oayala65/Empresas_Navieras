# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Ruta del archivo
file_path = "TAGUATO_09_04_2025-13_17_56_keras.xlsx"

# Cargar el archivo y ver las hojas disponibles
xls = pd.ExcelFile(file_path)
xls.sheet_names
# Out:
# ['Worksheet']

# %%
# Cargar la hoja en un DataFrame
df = pd.read_excel(xls, sheet_name="Work",parse_dates=["DATE/TIME(UTC)"])

# Mostrar las primeras filas del DataFrame
df.head()
# Out:
#        DATE/TIME(UTC)  FLOW DIARIO  FLOW PROPULSOR STB  FLOW GENERADOR STB  \
# 0 2025-03-25 00:00:16       4609.1                58.2                12.1
# 1 2025-03-25 00:01:17       4611.3                58.2                11.9
# 2 2025-03-25 00:02:18       4611.3                87.9                11.9
# 3 2025-03-25 00:03:19       4616.7               172.5                10.6
# 4 2025-03-25 00:04:20       4630.9               158.3                11.6
#
#    FLOW PROPULSOR BR  FLOW GENERADOR BR  TRIP DIARIO  TRIP PROPULSOR STB  \
# 0               39.2                0.0       752825               91129
# 1               74.9                0.0       752902               91130
# 2               74.9                0.0       752979               91132
# 3              207.5                0.0       753056               91134
# 4              200.0                0.0       753133               91137
#
#    TRIP GENERADOR STB  TRIP PROPULSOR BR  ...  PROPULSOR STB CILINDRO 8  \
# ...

# %%
df.isnull().sum()
# Out:
# DATE/TIME(UTC)        0
# FLOW DIARIO           0
# FLOW PROPULSOR STB    0
# FLOW GENERADOR STB    0
# FLOW PROPULSOR BR     0
#                      ..
# VELOCIDAD             0
# RACK PROPULSOR STB    0
# RACK PROPULSOR BR     0
# ECOSONDA/depth        0
# ECOSONDA/offset       0
# Length: 67, dtype: int64

# %%
df=df.dropna(axis=1)

# %%
df.T
# Out:
#                                     0                    1    \
# DATE/TIME(UTC)      2025-03-25 00:00:16  2025-03-25 00:01:17
# FLOW DIARIO                      4609.1               4611.3
# FLOW PROPULSOR STB                 58.2                 58.2
# FLOW GENERADOR STB                 12.1                 11.9
# FLOW PROPULSOR BR                  39.2                 74.9
# ...                                 ...                  ...
# VELOCIDAD                           0.0                  0.0
# RACK PROPULSOR STB             1.798358             1.798358
# RACK PROPULSOR BR              1.867563             1.863361
# ECOSONDA/depth                        0                    0
# ECOSONDA/offset                       0                    0
#
#                                     2                    3    \
# DATE/TIME(UTC)      2025-03-25 00:02:18  2025-03-25 00:03:19
# FLOW DIARIO                      4611.3               4616.7
# ...

# %%
df.columns
# Out:
# Index(['DATE/TIME(UTC)', 'Hora', 'RPM PROPULSOR STB', 'RPM PROPULSOR BR',
#        'LATITUD', 'LONGITUD', 'VELOCIDAD'],
#       dtype='object')

# %%
# Graficar con Seaborn
plt.figure(figsize=(15, 5))
sns.lineplot(x=df["DATE/TIME(UTC)"], y=df["VELOCIDAD"], marker="o")
# Personalizar la gráfica
plt.xlabel("Fecha y Hora (UTC)")
plt.ylabel("Velocidad")
plt.title("Velocidad vs. Tiempo (06:30 - 06:40 UTC)")
plt.xticks(rotation=45)  # Rotar etiquetas del eje X para mejor visualización
plt.grid(True)

# Mostrar la gráfica
plt.show()

# %%
# Filtrar datos entre las 06:30 y 06:40 UTC
hora_inicio = pd.to_datetime("2025-03-25 06:30:00")
hora_fin = pd.to_datetime("2025-03-25 06:40:00")
df_filtrado = df[(df["DATE/TIME(UTC)"] > hora_inicio) & (df["DATE/TIME(UTC)"] < hora_fin)]

# Graficar con Seaborn
plt.figure(figsize=(15, 5))
sns.lineplot(x=df_filtrado["DATE/TIME(UTC)"], y=df_filtrado["VELOCIDAD"], marker="o")
# Personalizar la gráfica
plt.xlabel("Fecha y Hora (UTC)")
plt.ylabel("Velocidad")
plt.title("Velocidad vs. Tiempo (06:30 - 06:40 UTC)")
plt.xticks(rotation=45)  # Rotar etiquetas del eje X para mejor visualización
plt.grid(True)

# Mostrar la gráfica
plt.show()

# %%
# Graficar con Seaborn
plt.figure(figsize=(15, 5))

hora_inicio = pd.to_datetime("2025-03-25 06:30:00")
hora_fin = pd.to_datetime("2025-03-25 06:40:00")
df_filtrado = df[(df["DATE/TIME(UTC)"] > hora_inicio) & (df["DATE/TIME(UTC)"] < hora_fin)]


sns.lineplot(x=df_filtrado["DATE/TIME(UTC)"], y=df_filtrado["RPM PROPULSOR STB"], marker="o")
sns.lineplot(x=df_filtrado["DATE/TIME(UTC)"], y=df_filtrado["RPM PROPULSOR BR"], marker="o")
# Personalizar la gráfica
plt.xlabel("Fecha y Hora (UTC)")
plt.ylabel("RPM")
plt.title("RPM vs. FECHA y HORA (06:30 - 06:40 UTC)")
plt.xticks(rotation=45)  # Rotar etiquetas del eje X para mejor visualización
plt.grid(True)

# Mostrar la gráfica
plt.show()
